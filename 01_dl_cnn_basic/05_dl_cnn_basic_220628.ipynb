# %% [markdown]
# ## **Dogs vs Cats image classification**

# %% [markdown]
# ### **1. Import libraries**

# %%
import os
import tensorflow as tf
import shutil
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### **2. Load the dataset**

# %%
os.environ['KAGGLE_CONFIG_DIR'] = '/content/'

# %%
# !chmod 600 /content/kaggle.json

# %%
# !kaggle competitions download -c dogs-vs-cats-redux-kernels-edition
# Out:
# Downloading dogs-vs-cats-redux-kernels-edition.zip to /content
#  98% 796M/814M [00:11<00:00, 81.1MB/s]
# 100% 814M/814M [00:11<00:00, 73.7MB/s]

# %%
# !unzip -q dogs-vs-cats-redux-kernels-edition.zip -d.
# !unzip -q train.zip -d.

# %%
len(os.listdir('/content/train/'))
# Out:
# 25000

# %%
os.mkdir('/content/data/')
os.mkdir('/content/data/cats/')
os.mkdir('/content/data/dogs/')

# %%
for i in os.listdir('/content/train/'):
  if 'cat' in i:
    shutil.copyfile('/content/train/'+i, '/content/data/cats/'+i )
  if 'dog' in i:
    shutil.copyfile('/content/train/'+i, '/content/data/dogs/'+i )

# %%
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    '/content/data/',
    image_size=(64, 64),
    batch_size=64,
    subset='training',
    validation_split=0.2,
    seed=42
)

valid_ds = tf.keras.preprocessing.image_dataset_from_directory(
    '/content/data/',
    image_size=(64, 64),
    batch_size=64,
    subset='validation',
    validation_split=0.2,
    seed=42
)
# Out:
# Found 25000 files belonging to 2 classes.
# Using 20000 files for training.
# Found 25000 files belonging to 2 classes.
# Using 5000 files for validation.

# %%
print(train_ds, valid_ds, sep='\n')
# Out:
# <BatchDataset element_spec=(TensorSpec(shape=(None, 64, 64, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>
# <BatchDataset element_spec=(TensorSpec(shape=(None, 64, 64, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %% [markdown]
# ### **3. Explore the data**

# %%
for i, target in train_ds.take(1):
  print(i[0])
  print(target[:10])
# Out:
# tf.Tensor(
# [[[216.11719 216.11719 208.11719]
#   [219.85156 219.85156 211.85156]
#   [217.11035 217.11035 209.11035]
#   ...
#   [218.26465 219.26465 202.01465]
#   [220.03223 221.03223 203.78223]
#   [224.01562 225.01562 207.76562]]
#
#  [[214.25    214.25    206.     ]
#   [215.75293 215.75293 207.50293]
#   [218.87012 218.87012 210.62012]
#   ...
#   [208.90918 209.90918 194.15918]
#   [211.57324 212.57324 196.82324]
#   [217.50879 218.50879 202.75879]]
#
#  [[211.02344 211.02344 199.02344]
#   [215.05469 215.05469 203.05469]
#   [218.21094 218.21094 206.21094]
#   ...
#   [210.87988 210.87988 198.87988]
#   [212.92188 212.92188 200.92188]
#   [215.13965 215.13965 203.13965]]
#
#  ...
#
#  [[179.50781 185.53125 183.83594]
#   [211.15625 212.15625 198.11523]
#   [205.50293 204.50293 199.54199]
#   ...
#   [217.19336 215.19336 200.19336]
#   [194.01074 192.01074 177.01074]
#   [211.49219 209.49219 194.49219]]
#
#  [[194.19043 199.21387 205.01855]
#   [190.95508 190.95508 180.66406]
#   [199.5     199.34082 191.85742]
#   ...
#   [210.68066 208.68066 193.68066]
#   [199.46973 197.46973 182.46973]
#   [195.80371 193.80371 178.80371]]
#
#  [[212.21973 216.24316 227.91797]
#   [192.02539 192.02539 184.02539]
#   [196.60352 196.56445 188.7207 ]
#   ...
#   [210.74023 208.74023 193.74023]
#   [215.70898 213.70898 198.70898]
#   [199.9209  197.9209  182.9209 ]]], shape=(64, 64, 3), dtype=float32)
# tf.Tensor([1 0 0 0 0 0 1 0 1 0], shape=(10,), dtype=int32)

# %%
plt.imshow(i[0].numpy().astype('uint8'))
plt.show()

# %% [markdown]
# ### **4. Preprocess the data**

# %%
def preprocessing(i, target):
  i = tf.cast(i/255.0, tf.float32)
  return i, target

train_ds = train_ds.map(preprocessing)
valid_ds = valid_ds.map(preprocessing)

# %%
for i, target in train_ds.take(1):
  print(i[0])
  print(target[:10])
# Out:
# tf.Tensor(
# [[[0.93602747 0.9752432  0.97720015]
#   [0.9566234  0.997415   0.9736462 ]
#   [0.97331685 0.9967946  0.98914486]
#   ...
#   [0.6900927  0.744627   0.7448721 ]
#   [0.6284639  0.65763056 0.68201786]
#   [0.23094745 0.23646216 0.21685432]]
#
#  [[0.43974036 0.46443972 0.44524357]
#   [0.59622586 0.6275984  0.58446115]
#   [0.7544826  0.7819336  0.7505936 ]
#   ...
#   [0.6332874  0.6801011  0.6803462 ]
#   [0.49942362 0.51204616 0.54121286]
#   [0.2178711  0.20696422 0.19360639]]
#
#  [[0.97267157 0.97735715 0.9958525 ]
#   [0.9739296  0.9824429  0.97919154]
#   [0.9666494  0.98922527 0.9895929 ]
#   ...
#   [0.5387408  0.5779833  0.5820006 ]
#   [0.50803846 0.51061195 0.5428424 ]
#   [0.22702205 0.20119295 0.19150199]]
#
#  ...
#
#  [[0.8576919  0.83808404 0.6114909 ]
#   [0.88933825 0.86580884 0.67058825]
#   [0.914141   0.8906116  0.7023763 ]
#   ...
#   [0.13210018 0.10035999 0.09251685]
#   [0.11597159 0.09636374 0.08459903]
#   [0.13668045 0.09599418 0.0928079 ]]
#
#  [[0.85043466 0.84142154 0.6584176 ]
#   [0.9246764  0.9129117  0.7483283 ]
#   [0.8972752  0.8855105  0.7090399 ]
#   ...
#   [0.10521216 0.07347196 0.06562883]
#   [0.11272787 0.09312002 0.08135532]
#   [0.10767081 0.08620749 0.07506128]]
#
#  [[0.8745098  0.84705883 0.6745098 ]
#   [0.8890376  0.87813073 0.7190621 ]
#   [0.925      0.8974265  0.7254902 ]
#   ...
#   [0.14462699 0.08960249 0.08543582]
#   [0.10496324 0.08927696 0.07751226]
#   [0.13480967 0.086893   0.08223613]]], shape=(64, 64, 3), dtype=float32)
# tf.Tensor([1 1 1 1 1 0 1 0 0 0], shape=(10,), dtype=int32)

# %% [markdown]
# ### **5. Build the model+Data augmentation/Dropout**

# %%
model = tf.keras.Sequential([
  tf.keras.layers.RandomFlip('horizontal', input_shape=(64, 64, 3)),
  tf.keras.layers.RandomRotation(0.2),
  tf.keras.layers.RandomZoom(0.2),
  tf.keras.layers.Conv2D(32, (3, 3), padding='same', activation='relu'), 
  tf.keras.layers.MaxPooling2D((2, 2)),
  tf.keras.layers.Conv2D(64, (3, 3), padding='same', activation='relu'), 
  tf.keras.layers.MaxPooling2D((2, 2)),
  tf.keras.layers.Dropout(0.2),
  tf.keras.layers.Conv2D(128, (3, 3), padding='same', activation='relu'), 
  tf.keras.layers.MaxPooling2D((2, 2)),
  tf.keras.layers.Dropout(0.2),
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(64, activation='relu'),
  tf.keras.layers.Dense(1 , activation='sigmoid'),
])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  random_flip (RandomFlip)    (None, 64, 64, 3)         0
#
#  random_rotation (RandomRota  (None, 64, 64, 3)        0
#  tion)
#
#  random_zoom (RandomZoom)    (None, 64, 64, 3)         0
#
#  conv2d (Conv2D)             (None, 64, 64, 32)        896
#
#  max_pooling2d (MaxPooling2D  (None, 32, 32, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 16, 16, 64)       0
#  2D)
#
#  dropout (Dropout)           (None, 16, 16, 64)        0
#
#  conv2d_2 (Conv2D)           (None, 16, 16, 128)       73856
#
#  max_pooling2d_2 (MaxPooling  (None, 8, 8, 128)        0
#  2D)
#
#  dropout_1 (Dropout)         (None, 8, 8, 128)         0
#
#  flatten (Flatten)           (None, 8192)              0
#
#  dense (Dense)               (None, 64)                524352
#
#  dense_1 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 617,665
# Trainable params: 617,665
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### **6. Compile the model**

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ### **7. Train the model+callback**

# %%
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath='model_checkpoint/save',
    save_weights_only=True,
    save_best_only=True,
    monitor='val_accuracy',
    mode='max',
    verbose=1
)

# %%
history = model.fit(train_ds, validation_data=valid_ds, epochs=20, callbacks=[model_checkpoint_callback])
# Out:
# Epoch 1/20
# 313/313 [==============================] - ETA: 0s - loss: 0.6688 - accuracy: 0.5843
# Epoch 1: val_accuracy improved from -inf to 0.63080, saving model to model_checkpoint/save
# 313/313 [==============================] - 34s 68ms/step - loss: 0.6688 - accuracy: 0.5843 - val_loss: 0.6238 - val_accuracy: 0.6308
# Epoch 2/20
# 308/313 [============================>.] - ETA: 0s - loss: 0.6054 - accuracy: 0.6709
# Epoch 2: val_accuracy improved from 0.63080 to 0.65860, saving model to model_checkpoint/save
# 313/313 [==============================] - 22s 68ms/step - loss: 0.6047 - accuracy: 0.6715 - val_loss: 0.6143 - val_accuracy: 0.6586
# Epoch 3/20
# 311/313 [============================>.] - ETA: 0s - loss: 0.5647 - accuracy: 0.7057
# Epoch 3: val_accuracy improved from 0.65860 to 0.71580, saving model to model_checkpoint/save
# 313/313 [==============================] - 21s 67ms/step - loss: 0.5645 - accuracy: 0.7060 - val_loss: 0.5429 - val_accuracy: 0.7158
# Epoch 4/20
# 312/313 [============================>.] - ETA: 0s - loss: 0.5411 - accuracy: 0.7245
# Epoch 4: val_accuracy improved from 0.71580 to 0.76180, saving model to model_checkpoint/save
# 313/313 [==============================] - 23s 73ms/step - loss: 0.5410 - accuracy: 0.7246 - val_loss: 0.4925 - val_accuracy: 0.7618
# Epoch 5/20
# 312/313 [============================>.] - ETA: 0s - loss: 0.5242 - accuracy: 0.7393
# Epoch 5: val_accuracy did not improve from 0.76180
# 313/313 [==============================] - 21s 65ms/step - loss: 0.5243 - accuracy: 0.7394 - val_loss: 0.5632 - val_accuracy: 0.7056
# Epoch 6/20
# 312/313 [============================>.] - ETA: 0s - loss: 0.5136 - accuracy: 0.7453
# Epoch 6: val_accuracy did not improve from 0.76180
# 313/313 [==============================] - 22s 68ms/step - loss: 0.5136 - accuracy: 0.7454 - val_loss: 0.5175 - val_accuracy: 0.7278
# Epoch 7/20
# 310/313 [============================>.] - ETA: 0s - loss: 0.4983 - accuracy: 0.7555
# Epoch 7: val_accuracy improved from 0.76180 to 0.77280, saving model to model_checkpoint/save
# 313/313 [==============================] - 21s 67ms/step - loss: 0.4979 - accuracy: 0.7559 - val_loss: 0.4721 - val_accuracy: 0.7728
# Epoch 8/20
# 310/313 [============================>.] - ETA: 0s - loss: 0.4900 - accuracy: 0.7620
# Epoch 8: val_accuracy improved from 0.77280 to 0.79200, saving model to model_checkpoint/save
# 313/313 [==============================] - 21s 67ms/step - loss: 0.4896 - accuracy: 0.7624 - val_loss: 0.4360 - val_accuracy: 0.7920
# Epoch 9/20
# 311/313 [============================>.] - ETA: 0s - loss: 0.4800 - accuracy: 0.7662
# Epoch 9: val_accuracy improved from 0.79200 to 0.79920, saving model to model_checkpoint/save
# 313/313 [==============================] - 25s 80ms/step - loss: 0.4796 - accuracy: 0.7666 - val_loss: 0.4249 - val_accuracy: 0.7992
# Epoch 10/20
# 312/313 [============================>.] - ETA: 0s - loss: 0.4712 - accuracy: 0.7733
# Epoch 10: val_accuracy did not improve from 0.79920
# 313/313 [==============================] - 20s 64ms/step - loss: 0.4711 - accuracy: 0.7734 - val_loss: 0.4284 - val_accuracy: 0.7960
# Epoch 11/20
# 312/313 [============================>.] - ETA: 0s - loss: 0.4608 - accuracy: 0.7815
# Epoch 11: val_accuracy did not improve from 0.79920
# 313/313 [==============================] - 21s 67ms/step - loss: 0.4607 - accuracy: 0.7816 - val_loss: 0.4620 - val_accuracy: 0.7722
# Epoch 12/20
# 312/313 [============================>.] - ETA: 0s - loss: 0.4571 - accuracy: 0.7818
# Epoch 12: val_accuracy improved from 0.79920 to 0.81620, saving model to model_checkpoint/save
# 313/313 [==============================] - 23s 71ms/step - loss: 0.4571 - accuracy: 0.7818 - val_loss: 0.3947 - val_accuracy: 0.8162
# Epoch 13/20
# 312/313 [============================>.] - ETA: 0s - loss: 0.4540 - accuracy: 0.7869
# Epoch 13: val_accuracy did not improve from 0.81620
# 313/313 [==============================] - 21s 67ms/step - loss: 0.4540 - accuracy: 0.7868 - val_loss: 0.4059 - val_accuracy: 0.8124
# Epoch 14/20
# 310/313 [============================>.] - ETA: 0s - loss: 0.4458 - accuracy: 0.7893
# Epoch 14: val_accuracy improved from 0.81620 to 0.82000, saving model to model_checkpoint/save
# 313/313 [==============================] - 20s 64ms/step - loss: 0.4464 - accuracy: 0.7889 - val_loss: 0.3959 - val_accuracy: 0.8200
# Epoch 15/20
# 312/313 [============================>.] - ETA: 0s - loss: 0.4367 - accuracy: 0.7942
# Epoch 15: val_accuracy improved from 0.82000 to 0.82160, saving model to model_checkpoint/save
# 313/313 [==============================] - 21s 66ms/step - loss: 0.4365 - accuracy: 0.7944 - val_loss: 0.3882 - val_accuracy: 0.8216
# Epoch 16/20
# 310/313 [============================>.] - ETA: 0s - loss: 0.4301 - accuracy: 0.7958
# Epoch 16: val_accuracy did not improve from 0.82160
# 313/313 [==============================] - 20s 62ms/step - loss: 0.4299 - accuracy: 0.7959 - val_loss: 0.3932 - val_accuracy: 0.8134
# Epoch 17/20
# 310/313 [============================>.] - ETA: 0s - loss: 0.4300 - accuracy: 0.8005
# Epoch 17: val_accuracy did not improve from 0.82160
# 313/313 [==============================] - 21s 65ms/step - loss: 0.4300 - accuracy: 0.8004 - val_loss: 0.4036 - val_accuracy: 0.8102
# Epoch 18/20
# 312/313 [============================>.] - ETA: 0s - loss: 0.4215 - accuracy: 0.8046
# Epoch 18: val_accuracy did not improve from 0.82160
# 313/313 [==============================] - 26s 80ms/step - loss: 0.4213 - accuracy: 0.8047 - val_loss: 0.4155 - val_accuracy: 0.8054
# Epoch 19/20
# 312/313 [============================>.] - ETA: 0s - loss: 0.4195 - accuracy: 0.8041
# Epoch 19: val_accuracy improved from 0.82160 to 0.83740, saving model to model_checkpoint/save
# 313/313 [==============================] - 22s 70ms/step - loss: 0.4194 - accuracy: 0.8041 - val_loss: 0.3582 - val_accuracy: 0.8374
# Epoch 20/20
# 312/313 [============================>.] - ETA: 0s - loss: 0.4146 - accuracy: 0.8048
# Epoch 20: val_accuracy did not improve from 0.83740
# 313/313 [==============================] - 24s 73ms/step - loss: 0.4144 - accuracy: 0.8049 - val_loss: 0.3582 - val_accuracy: 0.8352

# %% [markdown]
# ### **8. Evaluate the model**

# %%
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0.5, 1])
plt.legend(loc='lower right')

test_loss, test_acc = model.evaluate(valid_ds, verbose=2)
# Out:
# 79/79 - 4s - loss: 0.3582 - accuracy: 0.8352 - 4s/epoch - 50ms/step

# %% [markdown]
# ### **9. Load the previously saved weights**

# %%
model_cp = tf.keras.Sequential([
  tf.keras.layers.RandomFlip('horizontal', input_shape=(64, 64, 3)),
  tf.keras.layers.RandomRotation(0.2),
  tf.keras.layers.RandomZoom(0.2),
  tf.keras.layers.Conv2D(32, (3, 3), padding='same', activation='relu'), 
  tf.keras.layers.MaxPooling2D((2, 2)),
  tf.keras.layers.Conv2D(64, (3, 3), padding='same', activation='relu'), 
  tf.keras.layers.MaxPooling2D((2, 2)),
  tf.keras.layers.Dropout(0.2),
  tf.keras.layers.Conv2D(128, (3, 3), padding='same', activation='relu'), 
  tf.keras.layers.MaxPooling2D((2, 2)),
  tf.keras.layers.Dropout(0.2),
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(64, activation='relu'),
  tf.keras.layers.Dense(1 , activation='sigmoid'),
])

# %%
model_cp.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
model_cp.load_weights('model_checkpoint/save')
test_loss, test_acc = model_cp.evaluate(valid_ds, verbose=2)
# Out:
# 79/79 - 4s - loss: 0.3582 - accuracy: 0.8374 - 4s/epoch - 52ms/step

# %%
print('Test accuracy :', np.round(test_acc * 100, 4))
# Out:
# Test accuracy : 83.74
